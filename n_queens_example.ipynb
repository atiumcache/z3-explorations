# %%
import importlib
import n_queens
importlib.reload(n_queens)

n_queens.solve_queens(2)
n_queens.solve_queens(3)
n_queens.solve_queens(4)
n_queens.solve_queens(8)
# Out:
# No solution exists for 2 Queens
# Time Elapsed: 0.021799564361572266 seconds.
#
# No solution exists for 3 Queens
# Time Elapsed: 0.02590489387512207 seconds.
#
# Solution for 4 Queens:
# . . Q .
# Q . . .
# . . . Q
# . Q . .
# Time Elapsed: 0.02594447135925293 seconds.
#
# Solution for 8 Queens:
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# Time Elapsed: 0.07738518714904785 seconds.

# %%
n_queens.solve_queens(32)
# Out:
# Solution for 32 Queens:
# . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . .
# . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . .
# . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . .
# . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . .
# . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . .
# . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . .
# . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . .
# ...

# %%
n_queens.solve_queens(64)
# Out:
# Solution for 64 Queens:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . Q . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...
